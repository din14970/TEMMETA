# %% [markdown]
# # Import libraries for interactively working in the notebook

# %%
#Base modules
import sys
import os
from datetime import datetime as dati

#Basic 3rd party packages
import h5py
import numpy as np
import json

#GUI elements
import tkinter as Tk
from tkinter import filedialog

#For working with images
from PIL import Image
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib_scalebar.scalebar import ScaleBar, SI_LENGTH_RECIPROCAL

#for generating some random numbers
import random

# %%
# %matplotlib notebook

# %% [markdown]
# # My in-out modules for a few operations on Velox emd

# %%
import modules.io as io
import modules.plottingtools as pl

# %%
from modules.decorators import timeit

# %%
import importlib
importlib.reload(io)
# Out:
# <module 'modules.io' from '/Users/nielscautaerts/Documents/Projects/BigMax/3_Software/VeloxMeta/TEMMETA/modules/io.py'>

# %% [markdown]
# # Creating dummy hdf5 file

# %%
with h5py.File("example.hdf5", "w") as nf:
    g1 = nf.create_group("Group1")
    g2 = nf.create_group("Group2/NestedGroup1")
    size = (100, 100)
    data = np.random.rand(*size)
    ds1 = g1.create_dataset("RandomImage", data = data)
    ds2 = g2.create_dataset("RandomThing", data = "Random string")
    #add some attributes
    g1.attrs["Attribute1"] = "Whatwhat"
    g1.attrs["Listatr"] = [0, 1, 2, 4]
    g2.attrs["Bla"] = 2
    g2.attrs["hmm"] = "Boo"
    ds1.attrs["What"] = "This is a dataset"
    ds2.attrs["teehee"] = "What is this"

# %% [markdown]
# # Visual file opening

# %%
f = io.open_emd_gui()

# %% [markdown]
# # CLI file opening

# %%
filename = os.path.expanduser("~/ownCloud/emdData&Reader/TestData/April2019/1520 EDS-HAADF 20190410.emd")
f = h5py.File(filename, 'r')

# %% [markdown]
# # Inspection of HDF5 node

# %%
help(io.scan_hdf5_node)

# %%
f["Data"]["Image/1c887212b79849869d14fd2b03db2481"]["Data"].shape
# Out:
# (512, 512, 1)

# %%
for k, v in f["Data/Image"].items():
    print(v["Data"].shape)
# Out:
# (512, 512, 1)
# (512, 512, 1)
# (512, 512, 239)
# (512, 512, 1)

# %%
io.scan_hdf5_node(f["Data"])
# Out:
# Data
#     Image
#         1c887212b79849869d14fd2b03db2481
#              - Data  ((512, 512, 1), float32)
#              - FrameLookupTable  ((1,), uint32)
#              - Metadata  ((60000, 1), uint8)
#         515e962de04c4529b1e83a6c7ed565c7
#              - Data  ((512, 512, 1), float32)
#              - FrameLookupTable  ((1,), uint32)
#              - Metadata  ((60000, 1), uint8)
#         84c474d76cea419399ee5eac5d9838ac
#              - Data  ((512, 512, 239), uint16)
#              - FrameLookupTable  ((239,), uint32)
#              - Metadata  ((60000, 239), uint8)
#         ae260c6bc7ff47898f3321228d18ddbd
#              - Data  ((512, 512, 1), float32)
#              - FrameLookupTable  ((1,), uint32)
#              - Metadata  ((60000, 1), uint8)
#     Line
#          - fde442a54d7d4654b6386a1657c3629c  ((1,), object)
#     Spectrum
#         ac8fabd7c5f94c17ba39dfda043c79af
#              - Data  ((4096, 1), uint32)
#              - Metadata  ((60000, 1), uint8)
#     SpectrumImage
#         c31266600d6f46329a4fbafccbc195c8
#              - Data  ((27573394, 1), uint8)
#              - Metadata  ((60000, 1), uint8)
#              - SpectrumImageSettings  ((1,), object)
#     SpectrumStream
#         cffe1d0acd7149bdbcca393abf071280
#              - AcquisitionSettings  ((1,), object)
#              - Data  ((63401928, 1), uint16)
#              - FrameLocationTable  ((239, 1), uint64)
#              - Metadata  ((60000, 2), uint8)
#     Text
#          - d5346101ed08431c9e6870db645c6b4e  ((1,), object)

# %%
io.scan_hdf5_node(f["Operations"], full_path = True, recursive = False)

# %% [markdown]
# # Dealing with metadata

# %%
help(io.get_det_uuid)
help(io.get_meta_dict)
help(io.get_meta_dict_det_no)
help(io.print_pretty)
help(io.write_meta_json)    
help(io.read_meta_json)

# %% [markdown]
# ## Examples

# %%
meta_test = io.get_meta_dict_det_no(f, "Image", det_no=0, frame = 0)
meta_test2 = io.get_meta_dict_det_no(f, "Image", det_no=2, frame = 0)

# %%
io.print_pretty(meta_test)
# Out:
# {
#     "Acquisition": {
#         "AcquisitionDatetime": {
#             "DateTime": "0"
#         },
#         "AcquisitionStartDatetime": {
#             "DateTime": "1554902425"
#         },
#         "BeamType": "",
#         "SourceType": "Monochromator"
#     },
#     "BinaryResult": {
#         "AcquisitionUnit": "",
#         "CompositionType": "",
#         "Detector": "SuperXG1",
#         "Encoding": "",
#         "Offset": {
#             "x": "-9.016565482561257e-009",
#             "y": "-9.016565482561257e-009"
#         },
#         "PixelSize": {
#             "height": "3.522095891625491e-011",
#             "width": "3.522095891625491e-011"
#         },
#         "PixelUnitX": "m",
#         "PixelUnitY": "m"
#     },
#     "Core": {
#         "MetadataDefinitionVersion": "7.9",
#         "MetadataSchemaVersion": "v1/2013/07",
#         "guid": "00000000000000000000000000000000"
#     },
#     "CustomProperties": {
#         "Aperture[C1].Name": {
#             "type": "string",
#             "value": "2000"
#         },
#         "Aperture[C2].Name": {
#             "type": "string",
#             "value": "50"
#         },
#         "Aperture[C3].Name": {
#             "type": "string",
#             "value": "2000"
#         },
#         "Aperture[OBJ].Name": {
#             "type": "string",
#             "value": "None"
#         },
#         "Aperture[SA].Name": {
#             "type": "string",
#             "value": "None"
#         },
#         "Detectors[SuperXG11].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG11].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG11].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Detectors[SuperXG12].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG12].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG12].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Detectors[SuperXG13].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG13].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG13].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Detectors[SuperXG14].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG14].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG14].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Scan.ScanTransformation.A11": {
#             "type": "double",
#             "value": "1"
#         },
#         "Scan.ScanTransformation.A12": {
#             "type": "double",
#             "value": "0"
#         },
#         "Scan.ScanTransformation.A13": {
#             "type": "double",
#             "value": "-0.0308242"
#         },
#         "Scan.ScanTransformation.A21": {
#             "type": "double",
#             "value": "0"
#         },
#         "Scan.ScanTransformation.A22": {
#             "type": "double",
#             "value": "1"
#         },
#         "Scan.ScanTransformation.A23": {
#             "type": "double",
#             "value": "-0.0251362"
#         },
#         "StemMagnification": {
#             "type": "double",
#             "value": "5.1e+006"
#         }
#     },
#     "Detectors": {
#         "Detector-0": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "BF",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "37.480715999999987",
#             "Inserted": "false",
#             "Offset": "-1.0309000000000008"
#         },
#         "Detector-1": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "BM-Ceta",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-10": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "5.497787143782138",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG14",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "3603",
#             "LiveTime": "154.99064249999998",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "1481",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "377.09403922494323"
#         },
#         "Detector-2": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "DF2",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "49.655091999999975",
#             "Inserted": "false",
#             "Offset": "-1.4228525390625038"
#         },
#         "Detector-3": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "DF4",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "49.209071499999958",
#             "Inserted": "false",
#             "Offset": "-0.90857812499999469"
#         },
#         "Detector-4": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "EF-CCD",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-5": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "EF-CINEMA",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-6": {
#             "CollectionAngleRange": {
#                 "begin": "0.10235004544887286",
#                 "end": "0.20000000000000001"
#             },
#             "DetectorName": "HAADF",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "40.571440749408183",
#             "Inserted": "true",
#             "Offset": "-1.97"
#         },
#         "Detector-7": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "0.78539816339744828",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG11",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "3603",
#             "LiveTime": "154.99064249999998",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "1481",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "377.09403922494323"
#         },
#         "Detector-8": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "2.3561944901923448",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG12",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "3603",
#             "LiveTime": "154.99064249999998",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "1481",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "377.09403922494323"
#         },
#         "Detector-9": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "3.9269908169872414",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG13",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "3603",
#             "LiveTime": "154.99064249999998",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "1481",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "377.09403922494323"
#         }
#     },
#     "EnergyFilter": {
#         "EntranceApertureType": ""
#     },
#     "GasInjectionSystems": "",
#     "Instrument": {
#         "ComputerName": "TITAN52333710",
#         "ControlSoftwareVersion": "2.11.1",
#         "InstrumentClass": "Titan",
#         "InstrumentId": "3371",
#         "InstrumentModel": "Titan",
#         "Manufacturer": "FEI Company"
#     },
#     "Optics": {
#         "AccelerationVoltage": "300000",
#         "Apertures": {
#             "Aperture-0": {
#                 "Diameter": "0.002",
#                 "Enabled": "0",
#                 "MechanismType": "Motorized",
#                 "Name": "C1",
#                 "Number": "1",
#                 "PositionOffset": {
#                     "x": "-0.0051125781250000004",
#                     "y": "-0.00058984374999999998"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-1": {
#                 "Diameter": "5.0000000000000002e-005",
#                 "Enabled": "3",
#                 "MechanismType": "Motorized",
#                 "Name": "C2",
#                 "Number": "2",
#                 "PositionOffset": {
#                     "x": "0.0044281249999999998",
#                     "y": "-0.00015781249999999999"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-2": {
#                 "Diameter": "0.002",
#                 "Enabled": "0",
#                 "MechanismType": "Motorized",
#                 "Name": "C3",
#                 "Number": "3",
#                 "PositionOffset": {
#                     "x": "-0.0048928906250000001",
#                     "y": "-0.000606015625"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-3": {
#                 "MechanismType": "Motorized",
#                 "Name": "OBJ",
#                 "Number": "4",
#                 "PositionOffset": {
#                     "x": "-0.0064200000000000004",
#                     "y": "-0.001230234375"
#                 },
#                 "Type": "None"
#             },
#             "Aperture-4": {
#                 "MechanismType": "Manual",
#                 "Name": "SA",
#                 "Number": "5",
#                 "Type": "None"
#             }
#         },
#         "BeamConvergence": "0.017027808627007573",
#         "C1LensIntensity": "-0.36628735065460205",
#         "C2LensIntensity": "0.21393260359764099",
#         "C3LensIntensity": "0.35795029997825623",
#         "CameraLength": "0.076999999999999999",
#         "Defocus": "8.0010830968235017e-008",
#         "DiffractionLensIntensity": "0.41633844375610352",
#         "EFTEMOn": "false",
#         "ExtractorVoltage": "4050.018310546875",
#         "Focus": "8.0010830968235019e-005",
#         "FullScanFieldOfView": {
#             "x": "1.8033130965122514e-008",
#             "y": "1.8033130965122514e-008"
#         },
#         "GunLensSetting": "1",
#         "HighMagnificationMode": "None",
#         "IlluminationMode": "Probe",
#         "IntermediateLensIntensity": "-0.19491490721702576",
#         "LastMeasuredScreenCurrent": "3.3786876089422551e-010",
#         "MiniCondenserLensIntensity": "0.18086114525794983",
#         "ObjectiveLensIntensity": "0.88565826416015625",
#         "ObjectiveLensMode": "HM",
#         "OperatingMode": "2",
#         "ProbeMode": "1",
#         "Projector1LensIntensity": "-0.34385821223258972",
#         "Projector2LensIntensity": "-0.96843445301055908",
#         "ProjectorMode": "1",
#         "ScreenCurrent": "3.3786876089422551e-010",
#         "SpotIndex": "6",
#         "StemFocus": "0",
#         "TemOperatingSubMode": "None"
#     },
#     "Sample": "",
#     "Scan": {
#         "DwellTime": "3.9999999999999998e-006",
#         "FrameTime": "1.488912",
#         "LineIntegrationCount": "1",
#         "LineInterlacing": "1",
#         "LineTime": "0.002908",
#         "MainsLockOn": "false",
#         "ScanArea": {
#             "bottom": "1",
#             "left": "0",
#             "right": "1",
#             "top": "0"
#         },
#         "ScanRotation": "-0.12217304763960168",
#         "ScanSize": {
#             "height": "512",
#             "width": "512"
#         }
#     },
#     "Stage": {
#         "AlphaTilt": "0.010382475027923711",
#         "BetaTilt": "0.10271262647986627",
#         "HolderType": "FEI Double Tilt",
#         "Position": {
#             "x": "6.1326719999999998e-005",
#             "y": "8.4754904000000015e-005",
#             "z": "-0.00015332254387328596"
#         }
#     },
#     "Vacuum": {
#         "VacuumMode": "Ready"
#     }
# }

# %%
print(meta_test["Core"]["MetadataDefinitionVersion"])
# Out:
# 7.9

# %%
#accessing and converting the data in the metadata
timestamp = int(meta_test["Acquisition"]["AcquisitionStartDatetime"]["DateTime"])
print("Timestamp: ", timestamp)
starttime = dati.fromtimestamp(timestamp)
print("DateTime: ", starttime)
# Out:
# Timestamp:  1554902425
# DateTime:  2019-04-10 15:20:25

# %% [markdown]
# # Working with Data

# %% [markdown]
# ## Images

# %% [markdown]
# Saving an image to a file with a scalebar

# %%
help(io.plot_single_image)

# %%
im_stack = io.get_image_data_det_no(f, 2)
#first image in the stack
frame = 0
test_image = im_stack[:,:,frame]
metdat = io.get_meta_dict_det_no(f, "Image", det_no = 0, frame = frame)
io.plot_single_image(test_image, metdat, filename =  "testfigure.tiff", scale_bar = True, save_meta = True, show_fig = True,
                     imshow_kwargs = {"cmap" : "jet"})
# Out:
# <img src="data:image/png;base64,..." width="512">
# (<Figure size 512x512 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0xc17b3d650>)

# %%
io.save_all_image_frames(f, det_no = 2, name = "HAADFtest", path = "./Testimages/", imshow_kwargs = {"cmap": "Greys"})

# %% [markdown]
# ## SpectrumStream

# %% [markdown]
# Converting to a format that is nicer to work with. All data is stored in an io.SpectrumStream object in the stream variable

# %%
#d, md1, md2, flut = get_spectrum_stream_frames(f, 0)
stream, d, md1, md2, flut, frames = io.get_spectrum_stream(f, one_matrix = True, re_all = True)
# Out:
# 'get_spectrum_stream'  22342.66 ms

# %%
io.print_pretty(md1)
# Out:
# {
#     "Acquisition": {
#         "AcquisitionDatetime": {
#             "DateTime": "0"
#         },
#         "AcquisitionStartDatetime": {
#             "DateTime": "1554902425"
#         },
#         "BeamType": "",
#         "SourceType": "Monochromator"
#     },
#     "BinaryResult": {
#         "AcquisitionUnit": "",
#         "CompositionType": "",
#         "Detector": "SuperXG1",
#         "Encoding": "",
#         "Offset": {
#             "x": "-9.016565482561257e-009",
#             "y": "-9.016565482561257e-009"
#         },
#         "PixelSize": {
#             "height": "3.522095891625491e-011",
#             "width": "3.522095891625491e-011"
#         },
#         "PixelUnitX": "m",
#         "PixelUnitY": "m"
#     },
#     "Core": {
#         "MetadataDefinitionVersion": "7.9",
#         "MetadataSchemaVersion": "v1/2013/07",
#         "guid": "00000000000000000000000000000000"
#     },
#     "CustomProperties": {
#         "Aperture[C1].Name": {
#             "type": "string",
#             "value": "2000"
#         },
#         "Aperture[C2].Name": {
#             "type": "string",
#             "value": "50"
#         },
#         "Aperture[C3].Name": {
#             "type": "string",
#             "value": "2000"
#         },
#         "Aperture[OBJ].Name": {
#             "type": "string",
#             "value": "None"
#         },
#         "Aperture[SA].Name": {
#             "type": "string",
#             "value": "None"
#         },
#         "Detectors[SuperXG11].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG11].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG11].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Detectors[SuperXG12].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG12].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG12].Temperature": {
#             "type": "double",
#             "value": "203.35"
#         },
#         "Detectors[SuperXG13].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG13].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG13].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Detectors[SuperXG14].IncidentAngle": {
#             "type": "double",
#             "value": "0.0945968"
#         },
#         "Detectors[SuperXG14].SpectrumBeginEnergy": {
#             "type": "long",
#             "value": "150"
#         },
#         "Detectors[SuperXG14].Temperature": {
#             "type": "double",
#             "value": "203.25"
#         },
#         "Scan.ScanTransformation.A11": {
#             "type": "double",
#             "value": "1"
#         },
#         "Scan.ScanTransformation.A12": {
#             "type": "double",
#             "value": "0"
#         },
#         "Scan.ScanTransformation.A13": {
#             "type": "double",
#             "value": "0"
#         },
#         "Scan.ScanTransformation.A21": {
#             "type": "double",
#             "value": "0"
#         },
#         "Scan.ScanTransformation.A22": {
#             "type": "double",
#             "value": "1"
#         },
#         "Scan.ScanTransformation.A23": {
#             "type": "double",
#             "value": "0"
#         },
#         "StemMagnification": {
#             "type": "double",
#             "value": "5.1e+006"
#         }
#     },
#     "Detectors": {
#         "Detector-0": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "BF",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "37.480715999999987",
#             "Inserted": "false",
#             "Offset": "-1.0309000000000008"
#         },
#         "Detector-1": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "BM-Ceta",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-10": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "5.497787143782138",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG14",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "0",
#             "LiveTime": "0",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "0",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "0"
#         },
#         "Detector-2": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "DF2",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "49.655091999999975",
#             "Inserted": "false",
#             "Offset": "-1.4228525390625038"
#         },
#         "Detector-3": {
#             "CollectionAngleRange": {
#                 "begin": "0",
#                 "end": "0"
#             },
#             "DetectorName": "DF4",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "49.209071499999958",
#             "Inserted": "false",
#             "Offset": "-0.90857812499999469"
#         },
#         "Detector-4": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "EF-CCD",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-5": {
#             "Binning": {
#                 "height": "2",
#                 "width": "2"
#             },
#             "DarkGainCorrectionType": "2",
#             "DetectorName": "EF-CINEMA",
#             "DetectorType": "ImagingDetector",
#             "ExposureMode": "",
#             "ExposureTime": "0.040000000000000001",
#             "ReadOutArea": {
#                 "bottom": "2048",
#                 "left": "0",
#                 "right": "2048",
#                 "top": "0"
#             },
#             "Shutters": {
#                 "Shutter-0": {
#                     "Position": "PostSpecimen",
#                     "Type": "Electrostatic"
#                 }
#             }
#         },
#         "Detector-6": {
#             "CollectionAngleRange": {
#                 "begin": "0.10235004544887286",
#                 "end": "0.20000000000000001"
#             },
#             "DetectorName": "HAADF",
#             "DetectorType": "ScanningDetector",
#             "Enabled": "true",
#             "Gain": "40.571440749408183",
#             "Inserted": "true",
#             "Offset": "-1.97"
#         },
#         "Detector-7": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "0.78539816339744828",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG11",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "0",
#             "LiveTime": "0",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "0",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "0"
#         },
#         "Detector-8": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "2.3561944901923448",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG12",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "0",
#             "LiveTime": "0",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "0",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "0"
#         },
#         "Detector-9": {
#             "AnalyticalDetectorShutterState": "4",
#             "AzimuthAngle": "3.9269908169872414",
#             "BeginEnergy": "150",
#             "CollectionAngle": "0.17499999999999999",
#             "DetectorName": "SuperXG13",
#             "DetectorType": "AnalyticalDetector",
#             "Dispersion": "5",
#             "ElectronicsNoise": "28.600000000000001",
#             "ElevationAngle": "0.31415926999999999",
#             "Enabled": "true",
#             "InputCountRate": "0",
#             "LiveTime": "0",
#             "OffsetEnergy": "-475.69756499999994",
#             "OutputCountRate": "0",
#             "PulseProcessTime": "2.9081620097620193e-006",
#             "RealTime": "0"
#         }
#     },
#     "EnergyFilter": {
#         "EntranceApertureType": ""
#     },
#     "GasInjectionSystems": "",
#     "Instrument": {
#         "ComputerName": "TITAN52333710",
#         "ControlSoftwareVersion": "2.11.1",
#         "InstrumentClass": "Titan",
#         "InstrumentId": "3371",
#         "InstrumentModel": "Titan",
#         "Manufacturer": "FEI Company"
#     },
#     "Optics": {
#         "AccelerationVoltage": "300000",
#         "Apertures": {
#             "Aperture-0": {
#                 "Diameter": "0.002",
#                 "Enabled": "0",
#                 "MechanismType": "Motorized",
#                 "Name": "C1",
#                 "Number": "1",
#                 "PositionOffset": {
#                     "x": "-0.0051125781250000004",
#                     "y": "-0.00058984374999999998"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-1": {
#                 "Diameter": "5.0000000000000002e-005",
#                 "Enabled": "3",
#                 "MechanismType": "Motorized",
#                 "Name": "C2",
#                 "Number": "2",
#                 "PositionOffset": {
#                     "x": "0.0044281249999999998",
#                     "y": "-0.00015781249999999999"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-2": {
#                 "Diameter": "0.002",
#                 "Enabled": "0",
#                 "MechanismType": "Motorized",
#                 "Name": "C3",
#                 "Number": "3",
#                 "PositionOffset": {
#                     "x": "-0.0048928906250000001",
#                     "y": "-0.000606015625"
#                 },
#                 "Type": "Circular"
#             },
#             "Aperture-3": {
#                 "MechanismType": "Motorized",
#                 "Name": "OBJ",
#                 "Number": "4",
#                 "PositionOffset": {
#                     "x": "-0.0064200000000000004",
#                     "y": "-0.001230234375"
#                 },
#                 "Type": "None"
#             },
#             "Aperture-4": {
#                 "MechanismType": "Manual",
#                 "Name": "SA",
#                 "Number": "5",
#                 "Type": "None"
#             }
#         },
#         "BeamConvergence": "0.017027808627007573",
#         "C1LensIntensity": "-0.36628735065460205",
#         "C2LensIntensity": "0.21393260359764099",
#         "C3LensIntensity": "0.35795029997825623",
#         "CameraLength": "0.076999999999999999",
#         "Defocus": "8.0010830968235017e-008",
#         "DiffractionLensIntensity": "0.41633844375610352",
#         "EFTEMOn": "false",
#         "ExtractorVoltage": "4050.018310546875",
#         "Focus": "8.0010830968235019e-005",
#         "FullScanFieldOfView": {
#             "x": "1.8033130965122514e-008",
#             "y": "1.8033130965122514e-008"
#         },
#         "GunLensSetting": "1",
#         "HighMagnificationMode": "None",
#         "IlluminationMode": "Probe",
#         "IntermediateLensIntensity": "-0.19491490721702576",
#         "LastMeasuredScreenCurrent": "0",
#         "MiniCondenserLensIntensity": "0.18086114525794983",
#         "ObjectiveLensIntensity": "0.88565826416015625",
#         "ObjectiveLensMode": "HM",
#         "OperatingMode": "2",
#         "ProbeMode": "1",
#         "Projector1LensIntensity": "-0.34385821223258972",
#         "Projector2LensIntensity": "-0.96843445301055908",
#         "ProjectorMode": "1",
#         "ScreenCurrent": "0",
#         "SpotIndex": "6",
#         "StemFocus": "0",
#         "TemOperatingSubMode": "None"
#     },
#     "Sample": "",
#     "Scan": {
#         "DwellTime": "3.9999999999999998e-006",
#         "FrameTime": "1.488912",
#         "LineIntegrationCount": "1",
#         "LineInterlacing": "1",
#         "LineTime": "0.002908",
#         "MainsLockOn": "false",
#         "ScanArea": {
#             "bottom": "1",
#             "left": "0",
#             "right": "1",
#             "top": "0"
#         },
#         "ScanRotation": "-0.12217304763960168",
#         "ScanSize": {
#             "height": "512",
#             "width": "512"
#         }
#     },
#     "Stage": {
#         "AlphaTilt": "0.010382475027923711",
#         "BetaTilt": "0.10271262647986627",
#         "HolderType": "FEI Double Tilt",
#         "Position": {
#             "x": "6.132984e-005",
#             "y": "8.4754904000000015e-005",
#             "z": "-0.00015332254387328596"
#         }
#     },
#     "Vacuum": {
#         "VacuumMode": "Ready"
#     }
# }

# %% [markdown]
# There are two metadata arrays in the data, check their difference

# %%
import difflib

a = json.dumps(md1)
b = json.dumps(md2)

for i,s in enumerate(difflib.ndiff(a, b)):
    if s[0]==' ': continue
    elif s[0]=='-':
        print(u'Delete "{}" from position {}'.format(s[-1],i))
    elif s[0]=='+':
        print(u'Add "{}" to position {}'.format(s[-1],i))
# Out:
# Add "1" to position 435
# Add "5" to position 436
# Add "5" to position 437
# Add "4" to position 438
# Add "9" to position 439
# Add "2" to position 441
# Add "8" to position 442
# Add "0" to position 443
# Add "3" to position 444
# Add "3" to position 1119
# Add "." to position 1120
# Add "3" to position 1121
# Add "7" to position 1122
# Add "8" to position 1123
# Add "6" to position 1124
# Add "8" to position 1125
# Add "7" to position 1126
# Add "6" to position 1127
# Add "0" to position 1128
# Add "8" to position 1129
# Add "9" to position 1130
# Add "4" to position 1131
# Add "2" to position 1132
# Add "2" to position 1133
# Add "5" to position 1134
# Add "5" to position 1135
# Add "1" to position 1136
# Add "e" to position 1137
# Add "-" to position 1138
# Add "0" to position 1139
# Add "1" to position 1140
# Add "3" to position 1175
# Add "." to position 1176
# Add "3" to position 1177
# Add "7" to position 1178
# Add "8" to position 1179
# Add "6" to position 1180
# Add "8" to position 1181
# Add "7" to position 1182
# Add "6" to position 1183
# Add "0" to position 1184
# Add "8" to position 1185
# Add "9" to position 1186
# Add "4" to position 1187
# Add "2" to position 1188
# Add "2" to position 1189
# Add "5" to position 1190
# Add "5" to position 1191
# Add "1" to position 1192
# Add "e" to position 1193
# Add "-" to position 1194
# Add "0" to position 1195
# Add "1" to position 1196
# Add "6" to position 2629
# Add "7" to position 2630
# Add "1" to position 2631
# Add "9" to position 2633
# Add "9" to position 2634
# Add "9" to position 2635
# Add "9" to position 2636
# Add "9" to position 2637
# Add "9" to position 2638
# Add "9" to position 2639
# Add "9" to position 2640
# Delete "4" from position 2642
# Add "3" to position 5558
# Add "7" to position 5559
# Add "7" to position 5560
# Add "." to position 5561
# Add "9" to position 5563
# Add "4" to position 5564
# Add "0" to position 5565
# Add "3" to position 5566
# Add "9" to position 5567
# Add "2" to position 5568
# Add "2" to position 5569
# Add "4" to position 5570
# Add "9" to position 5571
# Add "4" to position 5572
# Add "3" to position 5573
# Add "2" to position 5574
# Add "3" to position 5575
# Add "1" to position 5592
# Add "5" to position 5593
# Add "4" to position 5594
# Add "." to position 5595
# Add "9" to position 5596
# Add "9" to position 5597
# Add "6" to position 5599
# Add "4" to position 5600
# Add "2" to position 5601
# Add "4" to position 5602
# Add "9" to position 5603
# Add "9" to position 5604
# Add "9" to position 5605
# Add "9" to position 5606
# Add "9" to position 5607
# Add "9" to position 5608
# Add "8" to position 5609
# Add "3" to position 5632
# Add "6" to position 5633
# Add "3" to position 5635
# Delete "0" from position 5659
# Add "1" to position 5660
# Add "4" to position 5661
# Add "8" to position 5662
# Add "1" to position 5663
# Add "3" to position 6111
# Add "7" to position 6112
# Add "7" to position 6113
# Add "." to position 6114
# Add "9" to position 6116
# Add "4" to position 6117
# Add "0" to position 6118
# Add "3" to position 6119
# Add "9" to position 6120
# Add "2" to position 6121
# Add "2" to position 6122
# Add "4" to position 6123
# Add "9" to position 6124
# Add "4" to position 6125
# Add "3" to position 6126
# Add "2" to position 6127
# Add "3" to position 6128
# Add "1" to position 6145
# Add "5" to position 6146
# Add "4" to position 6147
# Add "." to position 6148
# Add "9" to position 6149
# Add "9" to position 6150
# Add "6" to position 6152
# Add "4" to position 6153
# Add "2" to position 6154
# Add "4" to position 6155
# Add "9" to position 6156
# Add "9" to position 6157
# Add "9" to position 6158
# Add "9" to position 6159
# Add "9" to position 6160
# Add "9" to position 6161
# Add "8" to position 6162
# Add "3" to position 6185
# Add "6" to position 6186
# Add "3" to position 6188
# Delete "0" from position 6212
# Add "1" to position 6213
# Add "4" to position 6214
# Add "8" to position 6215
# Add "1" to position 6216
# Add "3" to position 6664
# Add "7" to position 6665
# Add "7" to position 6666
# Add "." to position 6667
# Add "9" to position 6669
# Add "4" to position 6670
# Add "0" to position 6671
# Add "3" to position 6672
# Add "9" to position 6673
# Add "2" to position 6674
# Add "2" to position 6675
# Add "4" to position 6676
# Add "9" to position 6677
# Add "4" to position 6678
# Add "3" to position 6679
# Add "2" to position 6680
# Add "3" to position 6681
# Add "1" to position 6698
# Add "5" to position 6699
# Add "4" to position 6700
# Add "." to position 6701
# Add "9" to position 6702
# Add "9" to position 6703
# Add "6" to position 6705
# Add "4" to position 6706
# Add "2" to position 6707
# Add "4" to position 6708
# Add "9" to position 6709
# Add "9" to position 6710
# Add "9" to position 6711
# Add "9" to position 6712
# Add "9" to position 6713
# Add "9" to position 6714
# Add "8" to position 6715
# Add "3" to position 6738
# Add "6" to position 6739
# Add "3" to position 6741
# Delete "0" from position 6765
# Add "1" to position 6766
# Add "4" to position 6767
# Add "8" to position 6768
# Add "1" to position 6769
# Add "3" to position 7217
# Add "7" to position 7218
# Add "7" to position 7219
# Add "." to position 7220
# Add "9" to position 7222
# Add "4" to position 7223
# Add "0" to position 7224
# Add "3" to position 7225
# Add "9" to position 7226
# Add "2" to position 7227
# Add "2" to position 7228
# Add "4" to position 7229
# Add "9" to position 7230
# Add "4" to position 7231
# Add "3" to position 7232
# Add "2" to position 7233
# Add "3" to position 7234
# Add "1" to position 7251
# Add "5" to position 7252
# Add "4" to position 7253
# Add "." to position 7254
# Add "9" to position 7255
# Add "9" to position 7256
# Add "6" to position 7258
# Add "4" to position 7259
# Add "2" to position 7260
# Add "4" to position 7261
# Add "9" to position 7262
# Add "9" to position 7263
# Add "9" to position 7264
# Add "9" to position 7265
# Add "9" to position 7266
# Add "9" to position 7267
# Add "8" to position 7268
# Add "3" to position 7291
# Add "6" to position 7292
# Add "3" to position 7294
# Delete "0" from position 7318
# Add "1" to position 7319
# Add "4" to position 7320
# Add "8" to position 7321
# Add "1" to position 7322
# Delete "3" from position 8585
# Add "2" to position 8586
# Add "-" to position 9248
# Add "." to position 9250
# Add "0" to position 9251
# Add "3" to position 9252
# Add "0" to position 9253
# Add "8" to position 9254
# Add "2" to position 9255
# Add "4" to position 9256
# Add "2" to position 9257
# Add "-" to position 9452
# Add "." to position 9454
# Add "0" to position 9455
# Add "2" to position 9456
# Add "5" to position 9457
# Add "1" to position 9458
# Add "3" to position 9459
# Add "6" to position 9460
# Add "2" to position 9461

# %% [markdown]
# The spectrumstream data is extremely sparse and must be intelligently worked with. Here you can see how much memory different storage methods would require for the same array. Definitely we want to go with some sparse matrix representation! Important also is how fast we can do operations on these matrices. As a general rule, CSR is fast to perform row operations on, while CSC is fast to perform column operations on. DOK is not fast for operation but easy and intuitive to construct.

# %%
dtsizetest = stream.data
print("DOK: {} MB".format(sys.getsizeof(dtsizetest)/1000000))
print("CSR: {} MB".format(dtsizetest.tocsr().data.nbytes/1000000))
print("CSC: {} MB".format(dtsizetest.tocsc().data.nbytes/1000000))
print("Full: {} MB".format(sys.getsizeof(dtsizetest.toarray())/1000000))
# Out:
# DOK: 41.943168 MB
# CSR: 1.481032 MB
# CSC: 1.481032 MB
# Full: 513248.591984 MB

# %% [markdown]
# Sum over all the pixels and frames to get a total spectrum

# %%
stream.plot_quick_spectrum(plot_channels = True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1c1f897f50>)

# %% [markdown]
# It is possible to import the stream as a list of frames or as one large matrix. The rows represent a unique scan position (in the large matrix this is (x, y, frame), in the frame by frame list this is (x, y)) and the column an energy channel. The value is the number of counts captured there.
#
# I've also implemented functions to switch between the large matrix representaiton and the list representation

# %%
strmlist = stream.get_frame_list()

# %% [markdown]
# Sum over all frames to get a 2D matrix representing the integrated stem edx data

# %%
smfrm = stream.get_frame_sum(comp_type = "csr")

# %% [markdown]
# Reshaping this into an intuitive 3D matrix with axes (channel, x, y). Querying stemedx[begin:end] slices across the channels

# %%
stemedx = stream.reshape_sparse_matrix(smfrm)

# %%
stemedx[3:6].shape
# Out:
# (3, 512, 512)

# %% [markdown]
# We can also import selected frames if we don't want all of them

# %%
someframes = io.get_spectrum_stream(f, frames = [0, 1,2,4], one_matrix = True)
someframes_list = io.get_spectrum_stream(f, frames = [0, 1,2,4], one_matrix = False)
# Out:
# 'get_spectrum_stream'  670.25 ms
# 'get_spectrum_stream'  635.92 ms

# %% [markdown]
# There are far fewer counts when we don't use all the frames

# %%
someframes_list.plot_quick_spectrum()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x119ee0e90>)

# %% [markdown]
# Let's now actually plot some images created from the spectrum by filtering/integrating on channels and reshaping into an image. First we determine the peaks.

# %%
fig, ax = stream.plot_quick_spectrum(plot_channels = False)
ax.set_xlim(0, 10)
ax.set_ylim(0,2500)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 2500)

# %%
from scipy.signal import find_peaks

# %%
peaks, props = find_peaks(stream.tot_spectrum, height = 300 , width = 10)

# %%
fig, ax = stream.plot_quick_spectrum(plot_channels = True)
ax.set_yscale('log')
ax.scatter(peaks, stream.tot_spectrum[peaks], label = "peaks ({})".format(len(peaks)), color = "C1")

w = 40
for i in peaks:
    ax.axvspan(i-w/2, i+w/2, alpha=0.2, color='red')

ax.set_xlim(0, 2500)
ax.set_ylim([None, 9000])
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Based on these peaks we can decide on channels we want to integrate. The counts are extremely low so we do a binning to see significant changes.

# %%
numsb = len(peaks[1:]) #the first entry is not of interest
ipc = 3
fig, ax = plt.subplots(numsb // ipc, ipc)
axes = ax.ravel()

rebin_peak_imgs = []

w=40
rbs = 64
for j, i in enumerate(peaks[1:]):
    energy = i*stream.disp/1000
    width = w*stream.disp/1000
    dt = stream.get_image_peak_sum(energy, width)
    dt_r = pl.rebin(dt, [rbs, rbs])
    rebin_peak_imgs.append(dt_r)
    axes[j].imshow(dt_r, cmap = "hot")
    axes[j].set_axis_off()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# I also built a shortcut function which also allows for including scale bars, but it does not yet include any binning options. In any case, one likely prefers full flexibility on creating these kinds of images. Below I illustrate this function, you can see that most pixels have 0 counts and only very few have 4 or 5.

# %%
help(stream.plot_energy_image)
# Out:
# Help on method plot_energy_image in module modules.io:
#
# plot_energy_image(energy: float, width: float, scale_bar: bool = True, show_fig: bool = True, dpi: int = 100, save_meta: bool = True, sb_settings: dict = {'location': 'lower right', 'color': 'k', 'length_fraction': 0.15}, imshow_kwargs: dict = {}, savefile: str = '') method of modules.io.SpectrumStream instance
#     Plot and potentially save an image representing the sum of counts over all frames
#     within a particular energy window.
#
#     Args:
#     energy (float) : the energy to plot in keV
#     width (float) : the energy window to integrate over
#     scale_bar (bool) = True : whether to add a scale bar to the image. Metadata must contain this information.
#     show_fig (bool) = True : whether to show the figure
#     dpi (int) = 100 : dpi to save the image with
#     save_meta (bool) = True : save the metadata also as a separate json file with the same filename as the image
#     sb_settings (dict) = {"location":'lower right', "color" : 'k', "length_fraction" : 0.15}: settings for the scale bar
#     imshow_kwargs (dict) : optional formating arguments passed to the pyplot.imshow function
#     savefile (str) : file to save the image to. If empty (default) will not save the file.

# %%
disp = stream.disp
energy = peaks[1]*disp/1000
width = w*disp/1000
dt = stream.get_image_peak_sum(energy, width)
dt_hst = dt.ravel()

plt.ion()
fig, ax = plt.subplots(1)
ax.hist(dt_hst)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([1.79322e+05, 0.00000e+00, 6.80700e+04, 0.00000e+00, 1.29770e+04,
#         0.00000e+00, 1.59800e+03, 0.00000e+00, 1.66000e+02, 1.10000e+01]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Checking that we don't lose any counts in the operations. All the counts in the window selected in the spectrum is equal to the total counts in the image.

# %%
stream.tot_spectrum[(peaks[1]-w//2) : (peaks[1]+w//2)].sum()
# Out:
# 99537

# %%
dt.sum()
# Out:
# 99537

# %%
stream.plot_energy_image(energy, width, imshow_kwargs = {"cmap" : "jet", "vmin" : 0, "vmax" : 2})
# Out:
# <img src="data:image/png;base64,..." width="512">
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 512x512 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x1194a3ad0>)

# %%
stream.plot_energy_image(peaks[2]/1000*disp, width, imshow_kwargs = {"cmap" : "hot"})
# Out:
# <img src="data:image/png;base64,..." width="512">
# (<Figure size 512x512 with 1 Axes>,
#  <matplotlib.axes._axes.Axes at 0x119a24f50>)

# %% [markdown]
# Finally we may construct an RGB image by combining separate images and mapping their intensity to the R, G and B channels. This is shown for peak 1, 2 and 4. Peak 4 appears to come fro the region in the lower left corner and probably is some other phase.

# %%
fig, ax = plt.subplots(1, figsize = (5, 5), frameon = False)

r = rebin_peak_imgs[1]
g = rebin_peak_imgs[2]
b = rebin_peak_imgs[4]

RGB = np.zeros((rbs,rbs,3), 'uint8')
RGB[..., 0] = r*256//np.max(r)
RGB[..., 1] = g*256//np.max(g)
RGB[..., 2] = b*256//np.max(b)

ax.imshow(RGB)
ax.set_axis_off()

#ax.imshow(rebin_peak_imgs[1], cmap = "Reds", alpha = 0.5)
#ax.imshow(rebin_peak_imgs[2], cmap = "Blues", alpha = 0.5)
#ax.imshow(rebin_peak_imgs[2], cmap = "Greens", alpha = 0.5)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Save your work

# %%
fig.savefig("RGBp124.png", dpi = 100)

# %% [markdown]
# # Hyperspy parsers

# %%
#Higher level 3rd party packages
import hyperspy.api as hs
# Out:
# WARNING:hyperspy_gui_traitsui:The nbAgg matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.

# %%
fhs = hs.load(filename)
# Out:
# WARNING:hyperspy.io_plugins.emd:The file contains only one spectrum stream

# %%
fhs
# Out:
# [<EDSTEMSpectrum, title: EDS, dimensions: (|4096)>,
#  <Signal2D, title: Al, dimensions: (|512, 512)>,
#  <Signal2D, title: Ti, dimensions: (|512, 512)>,
#  <Signal2D, title: HAADF, dimensions: (|512, 512)>,
#  <Signal2D, title: N, dimensions: (|512, 512)>,
#  <EDSTEMSpectrum, title: EDS, dimensions: (512, 512|4096)>]

# %%
#hyperspy interpreted metadata
help(type(fhs[5]))

# %%
fhs[5].original_metadata
# Out:
# ├── Acquisition
# │   ├── AcquisitionDatetime
# │   │   └── DateTime = 0
# │   ├── AcquisitionStartDatetime
# │   │   └── DateTime = 1554902425
# │   ├── BeamType =
# │   └── SourceType = Monochromator
# ├── BinaryResult
# │   ├── AcquisitionUnit =
# │   ├── CompositionType =
# │   ├── Detector = SuperXG1
# │   ├── Encoding =
# │   ├── Offset
# │   │   ├── x = -9.016565482561257e-009
# │   │   └── y = -9.016565482561257e-009
# │   ├── PixelSize
# │   │   ├── height = 3.522095891625491e-011
# │   │   └── width = 3.522095891625491e-011
# │   ├── PixelUnitX = m
# │   └── PixelUnitY = m
# ├── Core
# │   ├── MetadataDefinitionVersion = 7.9
# │   ├── MetadataSchemaVersion = v1/2013/07
# │   └── guid = 00000000000000000000000000000000
# ├── CustomProperties
# │   ├── Aperture[C1].Name
# │   │   ├── type = string
# │   │   └── value = 2000
# │   ├── Aperture[C2].Name
# │   │   ├── type = string
# │   │   └── value = 50
# │   ├── Aperture[C3].Name
# │   │   ├── type = string
# │   │   └── value = 2000
# │   ├── Aperture[OBJ].Name
# │   │   ├── type = string
# │   │   └── value = None
# │   ├── Aperture[SA].Name
# │   │   ├── type = string
# │   │   └── value = None
# │   ├── Detectors[SuperXG11].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG11].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG11].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Detectors[SuperXG12].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG12].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG12].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.35
# │   ├── Detectors[SuperXG13].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG13].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG13].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Detectors[SuperXG14].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG14].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG14].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Scan.ScanTransformation.A11
# │   │   ├── type = double
# │   │   └── value = 1
# │   ├── Scan.ScanTransformation.A12
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A13
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A21
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A22
# │   │   ├── type = double
# │   │   └── value = 1
# │   ├── Scan.ScanTransformation.A23
# │   │   ├── type = double
# │   │   └── value = 0
# │   └── StemMagnification
# │       ├── type = double
# │       └── value = 5.1e+006
# ├── Detectors
# │   ├── Detector-0
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = BF
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 37.480715999999987
# │   │   ├── Inserted = false
# │   │   └── Offset = -1.0309000000000008
# │   ├── Detector-1
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = BM-Ceta
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-10
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 5.497787143782138
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG14
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 0
# │   │   ├── LiveTime = 0
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 0
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0
# │   ├── Detector-2
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = DF2
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 49.655091999999975
# │   │   ├── Inserted = false
# │   │   └── Offset = -1.4228525390625038
# │   ├── Detector-3
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = DF4
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 49.209071499999958
# │   │   ├── Inserted = false
# │   │   └── Offset = -0.90857812499999469
# │   ├── Detector-4
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = EF-CCD
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-5
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = EF-CINEMA
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-6
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0.10235004544887286
# │   │   │   └── end = 0.20000000000000001
# │   │   ├── DetectorName = HAADF
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 40.571440749408183
# │   │   ├── Inserted = true
# │   │   └── Offset = -1.97
# │   ├── Detector-7
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 0.78539816339744828
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG11
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 0
# │   │   ├── LiveTime = 0
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 0
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0
# │   ├── Detector-8
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 2.3561944901923448
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG12
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 0
# │   │   ├── LiveTime = 0
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 0
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0
# │   └── Detector-9
# │       ├── AnalyticalDetectorShutterState = 4
# │       ├── AzimuthAngle = 3.9269908169872414
# │       ├── BeginEnergy = 150
# │       ├── CollectionAngle = 0.17499999999999999
# │       ├── DetectorName = SuperXG13
# │       ├── DetectorType = AnalyticalDetector
# │       ├── Dispersion = 5
# │       ├── ElectronicsNoise = 28.600000000000001
# │       ├── ElevationAngle = 0.31415926999999999
# │       ├── Enabled = true
# │       ├── InputCountRate = 0
# │       ├── LiveTime = 0
# │       ├── OffsetEnergy = -475.69756499999994
# │       ├── OutputCountRate = 0
# │       ├── PulseProcessTime = 2.9081620097620193e-006
# │       └── RealTime = 0
# ├── EnergyFilter
# │   └── EntranceApertureType =
# ├── GasInjectionSystems =
# ├── ImportedDataParameter
# │   ├── First_frame = 0
# │   ├── Last_frame = 239
# │   ├── Number_of_channels = 4096
# │   ├── Number_of_frames = 239
# │   └── Rebin_energy = 1
# ├── Instrument
# │   ├── ComputerName = TITAN52333710
# │   ├── ControlSoftwareVersion = 2.11.1
# │   ├── InstrumentClass = Titan
# │   ├── InstrumentId = 3371
# │   ├── InstrumentModel = Titan
# │   └── Manufacturer = FEI Company
# ├── Operations
# │   ├── DisplayLevelsOperation
# │   │   ├── 428674e8b1d346d384f78a50a2916a01
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/4bbe21c7f4de4fa3acba16d391650716
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 2
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   ├── 8d0163235144431192d4a7f594d4a5a7
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/6cd6d30808444e74a171b783ca0cccb2
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 4
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   ├── ec8cf56b1c2444afb373b1c689e847b4
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/77fabfd326e244c8b3393805c2c3b40b
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 1
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   └── f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       └── outputs <list>
# │   │           ╠══ [0]
# │   │           ║   ╠══ inputIndex = 0
# │   │           ║   ╠══ operation = /Presentation/Displays/ImageDisplay/21b2565253e9487eac1c141bd2e0a031
# │   │           ║   ╚══ outputIndex = 0
# │   │           ╚══ [1]
# │   │               ╠══ inputIndex = 3
# │   │               ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │               ╚══ outputIndex = 0
# │   ├── EDSInputOperation
# │   │   └── c270ee0362b540eca5bcc84428ef9e48
# │   │       ├── dataPath = /Data/SpectrumStream/cffe1d0acd7149bdbcca393abf071280
# │   │       ├── detector = Summed
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Operations/SpectrumQuantificationOperation/21222534770b431db87c11ce1de61a3d', 'inputIndex': '0'}]
# │   ├── ImageQuantificationOperation
# │   │   └── f5508dcaa99f4dcfb178763567ab7a10
# │   │       ├── absorptionCorrection
# │   │       │   ├── calibrationError = 5
# │   │       │   ├── density = 1
# │   │       │   ├── sampleThickness = 4.9999999999999998e-008
# │   │       │   ├── useAbsorptionCorrection = false
# │   │       │   └── useDensity = false
# │   │       ├── backgroundCorrection
# │   │       │   ├── backgroundModel = None
# │   │       │   ├── backgroundModelModeled
# │   │       │   │   └── useBackgroundWindows = true
# │   │       │   ├── backgroundModelMultiPoly
# │   │       │   │   ├── backgroundOrder = 1
# │   │       │   │   ├── peakOrder = 1
# │   │       │   │   └── useBackgroundWindows = true
# │   │       │   ├── backgroundWindows =
# │   │       │   └── useManualBackgroundWindows = false
# │   │       ├── colormixSelection <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ color = #ffffff
# │   │       │   ║   ╠══ name = HAADF
# │   │       │   ║   ╠══ selected = false
# │   │       │   ║   ╚══ stem = true
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ color = #00ff00
# │   │       │   ║   ╠══ name = N
# │   │       │   ║   ╠══ selected = false
# │   │       │   ║   ╚══ stem = false
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ color = #ff0000
# │   │       │   ║   ╠══ name = Al
# │   │       │   ║   ╠══ selected = true
# │   │       │   ║   ╚══ stem = false
# │   │       │   ╚══ [3]
# │   │       │       ╠══ color = #2040ff
# │   │       │       ╠══ name = Ti
# │   │       │       ╠══ selected = true
# │   │       │       ╚══ stem = false
# │   │       ├── dataPath = /Data/SpectrumImage/c31266600d6f46329a4fbafccbc195c8
# │   │       ├── elementProperties <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 1
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 2
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [10]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 11
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [11]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 12
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [12]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 13
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [13]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 14
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [14]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 15
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [15]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 16
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [16]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 17
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [17]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 18
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [18]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 19
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [19]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 20
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 3
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [20]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 21
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [21]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 22
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [22]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 23
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [23]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 24
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [24]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 25
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [25]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 26
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [26]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 27
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [27]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 28
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [28]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 29
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [29]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 30
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [3]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 4
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [30]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 31
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [31]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 32
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [32]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 33
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [33]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 34
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [34]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 35
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [35]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 36
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [36]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 37
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [37]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 38
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [38]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 39
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [39]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 40
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [4]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 5
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [40]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 41
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [41]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 42
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [42]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 43
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [43]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 44
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [44]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 45
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [45]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 46
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [46]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 47
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [47]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 48
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [48]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 49
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [49]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 50
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [5]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 6
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [50]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 51
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [51]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 52
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [52]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 53
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [53]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 54
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [54]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 55
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [55]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 56
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [56]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 57
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [57]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 58
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [58]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 59
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [59]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 60
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [6]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 7
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [60]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 61
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [61]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 62
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [62]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 63
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [63]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 64
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [64]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 65
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [65]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 66
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [66]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 67
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [67]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 68
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [68]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 69
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [69]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 70
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [7]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 8
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [70]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 71
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [71]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 72
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [72]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 73
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [73]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 74
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [74]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 75
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [75]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 76
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [76]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 77
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [77]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 78
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [78]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 79
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [79]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 80
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [8]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 9
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [80]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 81
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [81]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 82
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [82]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 83
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [83]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 84
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [84]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 85
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [85]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 86
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [86]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 87
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [87]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 88
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [88]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 89
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [89]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 90
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [9]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 10
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [90]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 91
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [91]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 92
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [92]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 93
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [93]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 94
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [94]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 95
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [95]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 96
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [96]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 97
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [97]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 98
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╚══ [98]
# │   │       │       ╠══ atomicShellFamily = L
# │   │       │       ╠══ defaultLineSelect = true
# │   │       │       ╠══ element = 99
# │   │       │       ╠══ includeInAutoPeakId = false
# │   │       │       ╠══ quantify = true
# │   │       │       ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       ├── elementSelection = ['7', '13', '22']
# │   │       ├── elementsIdentified =
# │   │       ├── ionizationCrossSectionModel = Brown_Powell
# │   │       ├── outputs <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/DisplayLevelsOperation/428674e8b1d346d384f78a50a2916a01
# │   │       │   ║   ╚══ outputIndex = 7
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/IntensityProfileOperation/db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       │   ║   ╚══ outputIndex = 13
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/DisplayLevelsOperation/f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       │   ║   ╚══ outputIndex = 13
# │   │       │   ╠══ [3]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/IntensityProfileOperation/3fb6341b388040d8b410e6bad5dfd671
# │   │       │   ║   ╚══ outputIndex = 22
# │   │       │   ╚══ [4]
# │   │       │       ╠══ inputIndex = 0
# │   │       │       ╠══ operation = /Operations/DisplayLevelsOperation/8d0163235144431192d4a7f594d4a5a7
# │   │       │       ╚══ outputIndex = 22
# │   │       ├── quantificationKernelFilter = Blur
# │   │       ├── quantificationKernelFilterSigma = 2
# │   │       ├── quantificationKernelFilterSize = 9
# │   │       ├── quantificationMode = Integration
# │   │       ├── quantificationRadialFilterEdge = 0.050000000000000003
# │   │       ├── quantificationWienerFilterFrequency = 0.80000000000000004
# │   │       ├── spectralFilter = Gaussian
# │   │       ├── spectralFilterSigma = 1
# │   │       ├── spectralFilterSize = 3
# │   │       ├── useOptimizedCalibration = false
# │   │       ├── useQuantificationKernelFilter = true
# │   │       └── useSpectralFilter = false
# │   ├── IntensityProfileOperation
# │   │   ├── 3fb6341b388040d8b410e6bad5dfd671
# │   │   │   ├── dataPath = /Data/Line/fde442a54d7d4654b6386a1657c3629c
# │   │   │   └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/PlotDisplay/ec1a711cb61942d2a2962394e09b5bc2', 'inputIndex': '1'}]
# │   │   └── db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       ├── dataPath = /Data/Line/fde442a54d7d4654b6386a1657c3629c
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/PlotDisplay/ec1a711cb61942d2a2962394e09b5bc2', 'inputIndex': '0'}]
# │   ├── MixOperation
# │   │   └── c52ebd2c9a0e41b2be37e58f32898f0f
# │   │       ├── blend <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ factor = 0
# │   │       │   ║   ╠══ input = 1
# │   │       │   ║   ╚══ mode = true
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ factor = 0
# │   │       │   ║   ╠══ input = 2
# │   │       │   ║   ╚══ mode = false
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ factor = 1
# │   │       │   ║   ╠══ input = 3
# │   │       │   ║   ╚══ mode = false
# │   │       │   ╚══ [3]
# │   │       │       ╠══ factor = 1
# │   │       │       ╠══ input = 4
# │   │       │       ╚══ mode = false
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/ImageDisplay/eabe3bad22784cf6a1423b0aad5cf67e', 'inputIndex': '0'}]
# │   ├── Operations
# │   │   └── operations <list>
# │   │       ╠══ [0]
# │   │       ║   ╚══ MixOperation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │       ╠══ [1]
# │   │       ║   ╚══ ImageQuantificationOperation = /Operations/ImageQuantificationOperation/f5508dcaa99f4dcfb178763567ab7a10
# │   │       ╠══ [2]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       ╠══ [3]
# │   │       ║   ╚══ StemInputOperation = /Operations/StemInputOperation/b0b51c931ee148099dc404c85686e4f7
# │   │       ╠══ [4]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/ec8cf56b1c2444afb373b1c689e847b4
# │   │       ╠══ [5]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/428674e8b1d346d384f78a50a2916a01
# │   │       ╠══ [6]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/8d0163235144431192d4a7f594d4a5a7
# │   │       ╠══ [7]
# │   │       ║   ╚══ IntensityProfileOperation = /Operations/IntensityProfileOperation/db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       ╠══ [8]
# │   │       ║   ╚══ IntensityProfileOperation = /Operations/IntensityProfileOperation/3fb6341b388040d8b410e6bad5dfd671
# │   │       ╚══ [9]
# │   │           ╚══ EDSInputOperation = /Operations/EDSInputOperation/c270ee0362b540eca5bcc84428ef9e48
# │   └── StemInputOperation
# │       └── b0b51c931ee148099dc404c85686e4f7
# │           ├── dataPath = /Data/Image/84c474d76cea419399ee5eac5d9838ac
# │           ├── detector = HAADF
# │           ├── detectorInfo
# │           │   ├── name = HAADF
# │           │   └── segments =
# │           ├── outputs = [{'outputIndex': '0', 'operation': '/Operations/DisplayLevelsOperation/ec8cf56b1c2444afb373b1c689e847b4', 'inputIndex': '0'}]
# │           └── scanArea = ['0.000000', '0.000000', '1.000000', '1.000000']
# ├── Optics
# │   ├── AccelerationVoltage = 300000
# │   ├── Apertures
# │   │   ├── Aperture-0
# │   │   │   ├── Diameter = 0.002
# │   │   │   ├── Enabled = 0
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C1
# │   │   │   ├── Number = 1
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0051125781250000004
# │   │   │   │   └── y = -0.00058984374999999998
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-1
# │   │   │   ├── Diameter = 5.0000000000000002e-005
# │   │   │   ├── Enabled = 3
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C2
# │   │   │   ├── Number = 2
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = 0.0044281249999999998
# │   │   │   │   └── y = -0.00015781249999999999
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-2
# │   │   │   ├── Diameter = 0.002
# │   │   │   ├── Enabled = 0
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C3
# │   │   │   ├── Number = 3
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0048928906250000001
# │   │   │   │   └── y = -0.000606015625
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-3
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = OBJ
# │   │   │   ├── Number = 4
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0064200000000000004
# │   │   │   │   └── y = -0.001230234375
# │   │   │   └── Type = None
# │   │   └── Aperture-4
# │   │       ├── MechanismType = Manual
# │   │       ├── Name = SA
# │   │       ├── Number = 5
# │   │       └── Type = None
# │   ├── BeamConvergence = 0.017027808627007573
# │   ├── C1LensIntensity = -0.36628735065460205
# │   ├── C2LensIntensity = 0.21393260359764099
# │   ├── C3LensIntensity = 0.35795029997825623
# │   ├── CameraLength = 0.076999999999999999
# │   ├── Defocus = 8.0010830968235017e-008
# │   ├── DiffractionLensIntensity = 0.41633844375610352
# │   ├── EFTEMOn = false
# │   ├── ExtractorVoltage = 4050.018310546875
# │   ├── Focus = 8.0010830968235019e-005
# │   ├── FullScanFieldOfView
# │   │   ├── x = 1.8033130965122514e-008
# │   │   └── y = 1.8033130965122514e-008
# │   ├── GunLensSetting = 1
# │   ├── HighMagnificationMode = None
# │   ├── IlluminationMode = Probe
# │   ├── IntermediateLensIntensity = -0.19491490721702576
# │   ├── LastMeasuredScreenCurrent = 0
# │   ├── MiniCondenserLensIntensity = 0.18086114525794983
# │   ├── ObjectiveLensIntensity = 0.88565826416015625
# │   ├── ObjectiveLensMode = HM
# │   ├── OperatingMode = 2
# │   ├── ProbeMode = 1
# │   ├── Projector1LensIntensity = -0.34385821223258972
# │   ├── Projector2LensIntensity = -0.96843445301055908
# │   ├── ProjectorMode = 1
# │   ├── ScreenCurrent = 0
# │   ├── SpotIndex = 6
# │   ├── StemFocus = 0
# │   └── TemOperatingSubMode = None
# ├── Sample =
# ├── Scan
# │   ├── DwellTime = 3.9999999999999998e-006
# │   ├── FrameTime = 1.488912
# │   ├── LineIntegrationCount = 1
# │   ├── LineInterlacing = 1
# │   ├── LineTime = 0.002908
# │   ├── MainsLockOn = false
# │   ├── ScanArea
# │   │   ├── bottom = 1
# │   │   ├── left = 0
# │   │   ├── right = 1
# │   │   └── top = 0
# │   ├── ScanRotation = -0.12217304763960168
# │   └── ScanSize
# │       ├── height = 512
# │       └── width = 512
# ├── Stage
# │   ├── AlphaTilt = 0.010382475027923711
# │   ├── BetaTilt = 0.10271262647986627
# │   ├── HolderType = FEI Double Tilt
# │   └── Position
# │       ├── x = 6.132984e-005
# │       ├── y = 8.4754904000000015e-005
# │       └── z = -0.00015332254387328596
# └── Vacuum
#     └── VacuumMode = Ready

# %%
fhs[3].original_metadata
# Out:
# ├── Acquisition
# │   ├── AcquisitionDatetime
# │   │   └── DateTime = 0
# │   ├── AcquisitionStartDatetime
# │   │   └── DateTime = 1554902426
# │   ├── BeamType =
# │   └── SourceType = Monochromator
# ├── BinaryResult
# │   ├── AcquisitionUnit =
# │   ├── CompositionType =
# │   ├── Detector = HAADF
# │   ├── DetectorIndex = 6
# │   ├── Encoding =
# │   ├── Offset
# │   │   ├── x = -9.016565482561257e-009
# │   │   └── y = -9.016565482561257e-009
# │   ├── PixelSize
# │   │   ├── height = 3.522095891625491e-011
# │   │   └── width = 3.522095891625491e-011
# │   ├── PixelUnitX = m
# │   └── PixelUnitY = m
# ├── Core
# │   ├── MetadataDefinitionVersion = 7.9
# │   ├── MetadataSchemaVersion = v1/2013/07
# │   └── guid = 00000000000000000000000000000000
# ├── CustomProperties
# │   ├── Aperture[C1].Name
# │   │   ├── type = string
# │   │   └── value = 2000
# │   ├── Aperture[C2].Name
# │   │   ├── type = string
# │   │   └── value = 50
# │   ├── Aperture[C3].Name
# │   │   ├── type = string
# │   │   └── value = 2000
# │   ├── Aperture[OBJ].Name
# │   │   ├── type = string
# │   │   └── value = None
# │   ├── Aperture[SA].Name
# │   │   ├── type = string
# │   │   └── value = None
# │   ├── Detectors[SuperXG11].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG11].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG11].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Detectors[SuperXG12].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG12].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG12].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.35
# │   ├── Detectors[SuperXG13].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG13].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG13].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Detectors[SuperXG14].IncidentAngle
# │   │   ├── type = double
# │   │   └── value = 0.0945968
# │   ├── Detectors[SuperXG14].SpectrumBeginEnergy
# │   │   ├── type = long
# │   │   └── value = 150
# │   ├── Detectors[SuperXG14].Temperature
# │   │   ├── type = double
# │   │   └── value = 203.25
# │   ├── Scan.ScanTransformation.A11
# │   │   ├── type = double
# │   │   └── value = 1
# │   ├── Scan.ScanTransformation.A12
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A13
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A21
# │   │   ├── type = double
# │   │   └── value = 0
# │   ├── Scan.ScanTransformation.A22
# │   │   ├── type = double
# │   │   └── value = 1
# │   ├── Scan.ScanTransformation.A23
# │   │   ├── type = double
# │   │   └── value = 0
# │   └── StemMagnification
# │       ├── type = double
# │       └── value = 5.1e+006
# ├── DetectorMetadata
# │   ├── CollectionAngleRange
# │   │   ├── begin = 0.10235004544887286
# │   │   └── end = 0.20000000000000001
# │   ├── DetectorName = HAADF
# │   ├── DetectorType = ScanningDetector
# │   ├── Enabled = true
# │   ├── Gain = 40.571440749408183
# │   ├── Inserted = true
# │   └── Offset = -1.97
# ├── Detectors
# │   ├── Detector-0
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = BF
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 37.480715999999987
# │   │   ├── Inserted = false
# │   │   └── Offset = -1.0309000000000008
# │   ├── Detector-1
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = BM-Ceta
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-10
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 5.497787143782138
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG14
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 3664
# │   │   ├── LiveTime = 0.40547999999999995
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 1486
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0.99974281892792316
# │   ├── Detector-2
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = DF2
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 49.655091999999975
# │   │   ├── Inserted = false
# │   │   └── Offset = -1.4228525390625038
# │   ├── Detector-3
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0
# │   │   │   └── end = 0
# │   │   ├── DetectorName = DF4
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 49.209071499999958
# │   │   ├── Inserted = false
# │   │   └── Offset = -0.90857812499999469
# │   ├── Detector-4
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = EF-CCD
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-5
# │   │   ├── Binning
# │   │   │   ├── height = 2
# │   │   │   └── width = 2
# │   │   ├── DarkGainCorrectionType = 2
# │   │   ├── DetectorName = EF-CINEMA
# │   │   ├── DetectorType = ImagingDetector
# │   │   ├── ExposureMode =
# │   │   ├── ExposureTime = 0.040000000000000001
# │   │   ├── ReadOutArea
# │   │   │   ├── bottom = 2048
# │   │   │   ├── left = 0
# │   │   │   ├── right = 2048
# │   │   │   └── top = 0
# │   │   └── Shutters
# │   │       └── Shutter-0
# │   │           ├── Position = PostSpecimen
# │   │           └── Type = Electrostatic
# │   ├── Detector-6
# │   │   ├── CollectionAngleRange
# │   │   │   ├── begin = 0.10235004544887286
# │   │   │   └── end = 0.20000000000000001
# │   │   ├── DetectorName = HAADF
# │   │   ├── DetectorType = ScanningDetector
# │   │   ├── Enabled = true
# │   │   ├── Gain = 40.571440749408183
# │   │   ├── Inserted = true
# │   │   └── Offset = -1.97
# │   ├── Detector-7
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 0.78539816339744828
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG11
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 3664
# │   │   ├── LiveTime = 0.40547999999999995
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 1486
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0.99974281892792316
# │   ├── Detector-8
# │   │   ├── AnalyticalDetectorShutterState = 4
# │   │   ├── AzimuthAngle = 2.3561944901923448
# │   │   ├── BeginEnergy = 150
# │   │   ├── CollectionAngle = 0.17499999999999999
# │   │   ├── DetectorName = SuperXG12
# │   │   ├── DetectorType = AnalyticalDetector
# │   │   ├── Dispersion = 5
# │   │   ├── ElectronicsNoise = 28.600000000000001
# │   │   ├── ElevationAngle = 0.31415926999999999
# │   │   ├── Enabled = true
# │   │   ├── InputCountRate = 3664
# │   │   ├── LiveTime = 0.40547999999999995
# │   │   ├── OffsetEnergy = -475.69756499999994
# │   │   ├── OutputCountRate = 1486
# │   │   ├── PulseProcessTime = 2.9081620097620193e-006
# │   │   └── RealTime = 0.99974281892792316
# │   └── Detector-9
# │       ├── AnalyticalDetectorShutterState = 4
# │       ├── AzimuthAngle = 3.9269908169872414
# │       ├── BeginEnergy = 150
# │       ├── CollectionAngle = 0.17499999999999999
# │       ├── DetectorName = SuperXG13
# │       ├── DetectorType = AnalyticalDetector
# │       ├── Dispersion = 5
# │       ├── ElectronicsNoise = 28.600000000000001
# │       ├── ElevationAngle = 0.31415926999999999
# │       ├── Enabled = true
# │       ├── InputCountRate = 3664
# │       ├── LiveTime = 0.40547999999999995
# │       ├── OffsetEnergy = -475.69756499999994
# │       ├── OutputCountRate = 1486
# │       ├── PulseProcessTime = 2.9081620097620193e-006
# │       └── RealTime = 0.99974281892792316
# ├── EnergyFilter
# │   └── EntranceApertureType =
# ├── GasInjectionSystems =
# ├── Instrument
# │   ├── ComputerName = TITAN52333710
# │   ├── ControlSoftwareVersion = 2.11.1
# │   ├── InstrumentClass = Titan
# │   ├── InstrumentId = 3371
# │   ├── InstrumentModel = Titan
# │   └── Manufacturer = FEI Company
# ├── Operations
# │   ├── DisplayLevelsOperation
# │   │   ├── 428674e8b1d346d384f78a50a2916a01
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/4bbe21c7f4de4fa3acba16d391650716
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 2
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   ├── 8d0163235144431192d4a7f594d4a5a7
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/6cd6d30808444e74a171b783ca0cccb2
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 4
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   ├── ec8cf56b1c2444afb373b1c689e847b4
# │   │   │   └── outputs <list>
# │   │   │       ╠══ [0]
# │   │   │       ║   ╠══ inputIndex = 0
# │   │   │       ║   ╠══ operation = /Presentation/Displays/ImageDisplay/77fabfd326e244c8b3393805c2c3b40b
# │   │   │       ║   ╚══ outputIndex = 0
# │   │   │       ╚══ [1]
# │   │   │           ╠══ inputIndex = 1
# │   │   │           ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │   │           ╚══ outputIndex = 0
# │   │   └── f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       └── outputs <list>
# │   │           ╠══ [0]
# │   │           ║   ╠══ inputIndex = 0
# │   │           ║   ╠══ operation = /Presentation/Displays/ImageDisplay/21b2565253e9487eac1c141bd2e0a031
# │   │           ║   ╚══ outputIndex = 0
# │   │           ╚══ [1]
# │   │               ╠══ inputIndex = 3
# │   │               ╠══ operation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │               ╚══ outputIndex = 0
# │   ├── EDSInputOperation
# │   │   └── c270ee0362b540eca5bcc84428ef9e48
# │   │       ├── dataPath = /Data/SpectrumStream/cffe1d0acd7149bdbcca393abf071280
# │   │       ├── detector = Summed
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Operations/SpectrumQuantificationOperation/21222534770b431db87c11ce1de61a3d', 'inputIndex': '0'}]
# │   ├── ImageQuantificationOperation
# │   │   └── f5508dcaa99f4dcfb178763567ab7a10
# │   │       ├── absorptionCorrection
# │   │       │   ├── calibrationError = 5
# │   │       │   ├── density = 1
# │   │       │   ├── sampleThickness = 4.9999999999999998e-008
# │   │       │   ├── useAbsorptionCorrection = false
# │   │       │   └── useDensity = false
# │   │       ├── backgroundCorrection
# │   │       │   ├── backgroundModel = None
# │   │       │   ├── backgroundModelModeled
# │   │       │   │   └── useBackgroundWindows = true
# │   │       │   ├── backgroundModelMultiPoly
# │   │       │   │   ├── backgroundOrder = 1
# │   │       │   │   ├── peakOrder = 1
# │   │       │   │   └── useBackgroundWindows = true
# │   │       │   ├── backgroundWindows =
# │   │       │   └── useManualBackgroundWindows = false
# │   │       ├── colormixSelection <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ color = #ffffff
# │   │       │   ║   ╠══ name = HAADF
# │   │       │   ║   ╠══ selected = false
# │   │       │   ║   ╚══ stem = true
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ color = #00ff00
# │   │       │   ║   ╠══ name = N
# │   │       │   ║   ╠══ selected = false
# │   │       │   ║   ╚══ stem = false
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ color = #ff0000
# │   │       │   ║   ╠══ name = Al
# │   │       │   ║   ╠══ selected = true
# │   │       │   ║   ╚══ stem = false
# │   │       │   ╚══ [3]
# │   │       │       ╠══ color = #2040ff
# │   │       │       ╠══ name = Ti
# │   │       │       ╠══ selected = true
# │   │       │       ╚══ stem = false
# │   │       ├── dataPath = /Data/SpectrumImage/c31266600d6f46329a4fbafccbc195c8
# │   │       ├── elementProperties <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 1
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 2
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [10]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 11
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [11]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 12
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [12]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 13
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [13]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 14
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [14]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 15
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [15]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 16
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [16]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 17
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [17]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 18
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [18]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 19
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [19]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 20
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 3
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [20]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 21
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [21]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 22
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [22]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 23
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [23]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 24
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [24]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 25
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [25]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 26
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [26]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 27
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [27]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 28
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [28]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 29
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [29]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 30
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [3]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 4
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [30]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 31
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [31]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 32
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [32]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 33
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [33]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 34
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [34]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 35
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [35]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 36
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [36]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 37
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [37]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 38
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [38]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 39
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [39]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 40
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [4]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 5
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [40]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 41
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [41]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 42
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [42]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 43
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [43]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 44
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}, {'L2': 'K'}]
# │   │       │   ╠══ [44]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 45
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [45]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 46
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [46]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 47
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [47]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 48
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [48]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 49
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [49]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 50
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [5]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 6
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [50]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 51
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [51]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 52
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [52]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 53
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [53]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 54
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [54]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 55
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [55]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 56
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [56]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 57
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [57]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 58
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [58]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 59
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [59]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 60
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [6]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 7
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [60]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 61
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [61]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 62
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [62]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 63
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [63]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 64
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [64]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 65
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [65]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 66
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [66]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 67
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [67]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 68
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [68]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 69
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [69]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 70
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [7]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 8
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [70]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 71
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [71]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 72
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [72]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 73
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [73]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 74
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [74]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 75
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [75]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 76
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [76]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 77
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [77]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 78
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [78]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 79
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [79]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 80
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [8]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 9
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [80]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 81
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [81]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 82
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [82]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 83
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [83]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 84
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [84]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 85
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [85]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 86
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [86]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 87
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [87]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 88
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [88]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 89
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [89]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 90
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [9]
# │   │       │   ║   ╠══ atomicShellFamily = K
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 10
# │   │       │   ║   ╠══ includeInAutoPeakId = true
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'L3': 'K'}]
# │   │       │   ╠══ [90]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 91
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [91]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 92
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [92]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 93
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [93]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 94
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [94]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 95
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [95]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 96
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [96]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 97
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╠══ [97]
# │   │       │   ║   ╠══ atomicShellFamily = L
# │   │       │   ║   ╠══ defaultLineSelect = true
# │   │       │   ║   ╠══ element = 98
# │   │       │   ║   ╠══ includeInAutoPeakId = false
# │   │       │   ║   ╠══ quantify = true
# │   │       │   ║   ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       │   ╚══ [98]
# │   │       │       ╠══ atomicShellFamily = L
# │   │       │       ╠══ defaultLineSelect = true
# │   │       │       ╠══ element = 99
# │   │       │       ╠══ includeInAutoPeakId = false
# │   │       │       ╠══ quantify = true
# │   │       │       ╚══ xrayTransitions = [{'M5': 'L3'}, {'M4': 'L3'}]
# │   │       ├── elementSelection = ['7', '13', '22']
# │   │       ├── elementsIdentified =
# │   │       ├── ionizationCrossSectionModel = Brown_Powell
# │   │       ├── outputs <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/DisplayLevelsOperation/428674e8b1d346d384f78a50a2916a01
# │   │       │   ║   ╚══ outputIndex = 7
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/IntensityProfileOperation/db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       │   ║   ╚══ outputIndex = 13
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/DisplayLevelsOperation/f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       │   ║   ╚══ outputIndex = 13
# │   │       │   ╠══ [3]
# │   │       │   ║   ╠══ inputIndex = 0
# │   │       │   ║   ╠══ operation = /Operations/IntensityProfileOperation/3fb6341b388040d8b410e6bad5dfd671
# │   │       │   ║   ╚══ outputIndex = 22
# │   │       │   ╚══ [4]
# │   │       │       ╠══ inputIndex = 0
# │   │       │       ╠══ operation = /Operations/DisplayLevelsOperation/8d0163235144431192d4a7f594d4a5a7
# │   │       │       ╚══ outputIndex = 22
# │   │       ├── quantificationKernelFilter = Blur
# │   │       ├── quantificationKernelFilterSigma = 2
# │   │       ├── quantificationKernelFilterSize = 9
# │   │       ├── quantificationMode = Integration
# │   │       ├── quantificationRadialFilterEdge = 0.050000000000000003
# │   │       ├── quantificationWienerFilterFrequency = 0.80000000000000004
# │   │       ├── spectralFilter = Gaussian
# │   │       ├── spectralFilterSigma = 1
# │   │       ├── spectralFilterSize = 3
# │   │       ├── useOptimizedCalibration = false
# │   │       ├── useQuantificationKernelFilter = true
# │   │       └── useSpectralFilter = false
# │   ├── IntensityProfileOperation
# │   │   ├── 3fb6341b388040d8b410e6bad5dfd671
# │   │   │   ├── dataPath = /Data/Line/fde442a54d7d4654b6386a1657c3629c
# │   │   │   └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/PlotDisplay/ec1a711cb61942d2a2962394e09b5bc2', 'inputIndex': '1'}]
# │   │   └── db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       ├── dataPath = /Data/Line/fde442a54d7d4654b6386a1657c3629c
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/PlotDisplay/ec1a711cb61942d2a2962394e09b5bc2', 'inputIndex': '0'}]
# │   ├── MixOperation
# │   │   └── c52ebd2c9a0e41b2be37e58f32898f0f
# │   │       ├── blend <list>
# │   │       │   ╠══ [0]
# │   │       │   ║   ╠══ factor = 0
# │   │       │   ║   ╠══ input = 1
# │   │       │   ║   ╚══ mode = true
# │   │       │   ╠══ [1]
# │   │       │   ║   ╠══ factor = 0
# │   │       │   ║   ╠══ input = 2
# │   │       │   ║   ╚══ mode = false
# │   │       │   ╠══ [2]
# │   │       │   ║   ╠══ factor = 1
# │   │       │   ║   ╠══ input = 3
# │   │       │   ║   ╚══ mode = false
# │   │       │   ╚══ [3]
# │   │       │       ╠══ factor = 1
# │   │       │       ╠══ input = 4
# │   │       │       ╚══ mode = false
# │   │       └── outputs = [{'outputIndex': '0', 'operation': '/Presentation/Displays/ImageDisplay/eabe3bad22784cf6a1423b0aad5cf67e', 'inputIndex': '0'}]
# │   ├── Operations
# │   │   └── operations <list>
# │   │       ╠══ [0]
# │   │       ║   ╚══ MixOperation = /Operations/MixOperation/c52ebd2c9a0e41b2be37e58f32898f0f
# │   │       ╠══ [1]
# │   │       ║   ╚══ ImageQuantificationOperation = /Operations/ImageQuantificationOperation/f5508dcaa99f4dcfb178763567ab7a10
# │   │       ╠══ [2]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/f71b3b8f4c294f61b5bd4a55e59fec17
# │   │       ╠══ [3]
# │   │       ║   ╚══ StemInputOperation = /Operations/StemInputOperation/b0b51c931ee148099dc404c85686e4f7
# │   │       ╠══ [4]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/ec8cf56b1c2444afb373b1c689e847b4
# │   │       ╠══ [5]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/428674e8b1d346d384f78a50a2916a01
# │   │       ╠══ [6]
# │   │       ║   ╚══ DisplayLevelsOperation = /Operations/DisplayLevelsOperation/8d0163235144431192d4a7f594d4a5a7
# │   │       ╠══ [7]
# │   │       ║   ╚══ IntensityProfileOperation = /Operations/IntensityProfileOperation/db269850d9d64f31b6fcd26e6d2d8e1b
# │   │       ╠══ [8]
# │   │       ║   ╚══ IntensityProfileOperation = /Operations/IntensityProfileOperation/3fb6341b388040d8b410e6bad5dfd671
# │   │       ╚══ [9]
# │   │           ╚══ EDSInputOperation = /Operations/EDSInputOperation/c270ee0362b540eca5bcc84428ef9e48
# │   └── StemInputOperation
# │       └── b0b51c931ee148099dc404c85686e4f7
# │           ├── dataPath = /Data/Image/84c474d76cea419399ee5eac5d9838ac
# │           ├── detector = HAADF
# │           ├── detectorInfo
# │           │   ├── name = HAADF
# │           │   └── segments =
# │           ├── outputs = [{'outputIndex': '0', 'operation': '/Operations/DisplayLevelsOperation/ec8cf56b1c2444afb373b1c689e847b4', 'inputIndex': '0'}]
# │           └── scanArea = ['0.000000', '0.000000', '1.000000', '1.000000']
# ├── Optics
# │   ├── AccelerationVoltage = 300000
# │   ├── Apertures
# │   │   ├── Aperture-0
# │   │   │   ├── Diameter = 0.002
# │   │   │   ├── Enabled = 0
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C1
# │   │   │   ├── Number = 1
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0051125781250000004
# │   │   │   │   └── y = -0.00058984374999999998
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-1
# │   │   │   ├── Diameter = 5.0000000000000002e-005
# │   │   │   ├── Enabled = 3
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C2
# │   │   │   ├── Number = 2
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = 0.0044281249999999998
# │   │   │   │   └── y = -0.00015781249999999999
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-2
# │   │   │   ├── Diameter = 0.002
# │   │   │   ├── Enabled = 0
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = C3
# │   │   │   ├── Number = 3
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0048928906250000001
# │   │   │   │   └── y = -0.000606015625
# │   │   │   └── Type = Circular
# │   │   ├── Aperture-3
# │   │   │   ├── MechanismType = Motorized
# │   │   │   ├── Name = OBJ
# │   │   │   ├── Number = 4
# │   │   │   ├── PositionOffset
# │   │   │   │   ├── x = -0.0064200000000000004
# │   │   │   │   └── y = -0.001230234375
# │   │   │   └── Type = None
# │   │   └── Aperture-4
# │   │       ├── MechanismType = Manual
# │   │       ├── Name = SA
# │   │       ├── Number = 5
# │   │       └── Type = None
# │   ├── BeamConvergence = 0.017027808627007573
# │   ├── C1LensIntensity = -0.36628735065460205
# │   ├── C2LensIntensity = 0.21393260359764099
# │   ├── C3LensIntensity = 0.35795029997825623
# │   ├── CameraLength = 0.076999999999999999
# │   ├── Defocus = 8.0010830968235017e-008
# │   ├── DiffractionLensIntensity = 0.41633844375610352
# │   ├── EFTEMOn = false
# │   ├── ExtractorVoltage = 4050.018310546875
# │   ├── Focus = 8.0010830968235019e-005
# │   ├── FullScanFieldOfView
# │   │   ├── x = 1.8033130965122514e-008
# │   │   └── y = 1.8033130965122514e-008
# │   ├── GunLensSetting = 1
# │   ├── HighMagnificationMode = None
# │   ├── IlluminationMode = Probe
# │   ├── IntermediateLensIntensity = -0.19491490721702576
# │   ├── LastMeasuredScreenCurrent = 3.3596965906700904e-010
# │   ├── MiniCondenserLensIntensity = 0.18086114525794983
# │   ├── ObjectiveLensIntensity = 0.88565826416015625
# │   ├── ObjectiveLensMode = HM
# │   ├── OperatingMode = 2
# │   ├── ProbeMode = 1
# │   ├── Projector1LensIntensity = -0.34385821223258972
# │   ├── Projector2LensIntensity = -0.96843445301055908
# │   ├── ProjectorMode = 1
# │   ├── ScreenCurrent = 3.3596965906700904e-010
# │   ├── SpotIndex = 6
# │   ├── StemFocus = 0
# │   └── TemOperatingSubMode = None
# ├── Sample =
# ├── Scan
# │   ├── DwellTime = 3.9999999999999998e-006
# │   ├── FrameTime = 1.488912
# │   ├── LineIntegrationCount = 1
# │   ├── LineInterlacing = 1
# │   ├── LineTime = 0.002908
# │   ├── MainsLockOn = false
# │   ├── ScanArea
# │   │   ├── bottom = 1
# │   │   ├── left = 0
# │   │   ├── right = 1
# │   │   └── top = 0
# │   ├── ScanRotation = -0.12217304763960168
# │   └── ScanSize
# │       ├── height = 512
# │       └── width = 512
# ├── Stage
# │   ├── AlphaTilt = 0.010382475027923711
# │   ├── BetaTilt = 0.10271262647986627
# │   ├── HolderType = FEI Double Tilt
# │   └── Position
# │       ├── x = 6.132984e-005
# │       ├── y = 8.4754904000000015e-005
# │       └── z = -0.00015332254387328596
# └── Vacuum
#     └── VacuumMode = Ready
